# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=17YCvtfJwHfujpAm7OkgiHzPedgx3alWR')
df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  2000-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    843016.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    370874.0  ...
# 2       New York-Newark-Jersey City  New York County   1627388.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    164127.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    446151.0  ...
#
#    2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0   1948950.0   1959393.0   1968185.0   1983958.0   2002629.0   2023242.0
# 1    641585.0    645938.0    649394.0    651825.0    652146.0    655854.0
# 2   3115482.0   3135955.0   3162244.0   3175944.0   3183167.0   3201223.0
# 3    325559.0    331314.0    336172.0    340954.0    348051.0    356753.0
# 4    747531.0    753338.0    756832.0    759335.0    759078.0    762861.0
#
#    2022-04-30  2022-05-31  2022-06-30  2022-07-31
# 0   2045921.0   2059887.0   2065529.0   2063020.0
# 1    658997.0    665569.0    670335.0    673178.0
# 2   3249641.0   3302311.0   3324001.0   3331785.0
# 3    367285.0    375885.0    381273.0    382841.0
# 4    765671.0    772334.0    777664.0    781433.0
#
# [5 rows x 280 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23390 entries, 0 to 23389
# Columns: 280 entries, RegionID to 2022-07-31
# dtypes: float64(271), int64(3), object(6)
# memory usage: 50.0+ MB

# %%
df.shape
# Out:
# (23390, 280)

# %%
df.isnull().sum().sort_values()
# Out:
# RegionID          0
# SizeRank          0
# RegionName        0
# RegionType        0
# StateName         0
#               ...
# 2000-05-31    11624
# 2000-04-30    11668
# 2000-03-31    11685
# 2000-02-29    11706
# 2000-01-31    11789
# Length: 280, dtype: int64

# %%
df = df.rename(columns= {'RegionName':'Zipcode'})
df
# Out:
#        RegionID  SizeRank  Zipcode RegionType StateName State  \
# 0         61639         0    10025        Zip        NY    NY
# 1         84654         1    60657        Zip        IL    IL
# 2         61637         2    10023        Zip        NY    NY
# 3         91982         3    77494        Zip        TX    TX
# 4         84616         4    60614        Zip        IL    IL
# ...         ...       ...      ...        ...       ...   ...
# 23385     99547     34322    98068        Zip        WA    WA
# 23386     93733     34322    81225        Zip        CO    CO
# 23387     98152     34322    95375        Zip        CA    CA
# 23388     75924     34322    41101        Zip        KY    KY
# 23389     59376     34430     4109        Zip        ME    ME
#
#                       City                             Metro  \
# 0                 New York       New York-Newark-Jersey City
# 1                  Chicago          Chicago-Naperville-Elgin
# 2                 New York       New York-Newark-Jersey City
# 3                     Katy  Houston-The Woodlands-Sugar Land
# 4                  Chicago          Chicago-Naperville-Elgin
# ...                    ...                               ...
# 23385      Snoqualmie Pass                        Ellensburg
# 23386  Mount Crested Butte                               NaN
# 23387           Strawberry                            Sonora
# 23388              Ashland                Huntington-Ashland
# 23389             Portland           Portland-South Portland
#
#               CountyName  2000-01-31  ...  2021-10-31  2021-11-30  2021-12-31  \
# 0        New York County    843016.0  ...   1948950.0   1959393.0   1968185.0
# 1            Cook County    370874.0  ...    641585.0    645938.0    649394.0
# 2        New York County   1627388.0  ...   3115482.0   3135955.0   3162244.0
# 3          Harris County    164127.0  ...    325559.0    331314.0    336172.0
# 4            Cook County    446151.0  ...    747531.0    753338.0    756832.0
# ...                  ...         ...  ...         ...         ...         ...
# 23385    Kittitas County         NaN  ...    751746.0    779296.0    797926.0
# 23386    Gunnison County    353599.0  ...    699056.0    707203.0    722397.0
# 23387    Tuolumne County         NaN  ...    426056.0    421748.0    418881.0
# 23388        Boyd County     61665.0  ...     99835.0    100554.0    102301.0
# 23389  Cumberland County         NaN  ...    745728.0    751829.0    764551.0
#
#        2022-01-31  2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  \
# 0       1983958.0   2002629.0   2023242.0   2045921.0   2059887.0   2065529.0
# 1        651825.0    652146.0    655854.0    658997.0    665569.0    670335.0
# 2       3175944.0   3183167.0   3201223.0   3249641.0   3302311.0   3324001.0
# 3        340954.0    348051.0    356753.0    367285.0    375885.0    381273.0
# 4        759335.0    759078.0    762861.0    765671.0    772334.0    777664.0
# ...           ...         ...         ...         ...         ...         ...
# 23385    812942.0    822868.0    844258.0    876785.0    911684.0    944626.0
# 23386    733604.0    741966.0    742007.0    745301.0    750988.0    764798.0
# 23387    418710.0    429385.0    438033.0    447110.0    453889.0    457169.0
# 23388    103987.0    105719.0    106268.0    106877.0    107505.0    108404.0
# 23389    777417.0    792466.0    801481.0    808480.0    816588.0    826039.0
#
#        2022-07-31
# 0       2063020.0
# 1        673178.0
# 2       3331785.0
# 3        382841.0
# 4        781433.0
# ...           ...
# 23385    970874.0
# 23386    778511.0
# 23387    457778.0
# 23388    109289.0
# 23389    840195.0
#
# [23390 rows x 280 columns]

# %%
df = df.drop(columns=['RegionType', 'RegionID'])

# %%
print('Please enter the zipcode you would like to use for time series analysis:  ')
# Out:
# Please enter the zipcode you would like to use for time series analysis:

# %%
zipcode1 = int(input())
# Out:
# 02108

# %%
print('Would you like to compare it with another zipcode? Y or N? ')
# Out:
# Would you like to compare it with another zipcode? Y or N?

# %%
answer = input().upper()
# Out:
# 94560

# %%
if answer.upper == 'Y' or 'y':
  print('Enter the 2nd zipcode you would like to use: ')
  zipcode2 = int(input())

else:
  print('Great now lets move on with the analysis of ' + str(zipcode1))
# Out:
# Enter the 2nd zipcode you would like to use:
# 94560

# %%
#selected_zipcodes = np.logical_or(df['Zipcode'] == int(zipcode1), df['Zipcode'] == int(zipcode2))
zipcode1_bool = df['Zipcode'] == zipcode1

zipcode2_bool = df['Zipcode'] == zipcode2

# %%
#df[(df['Zipcode'] == zipcode1) | (df['Zipcode'] == zipcode2)]
df[zipcode2_bool]
# Out:
#       SizeRank  Zipcode StateName State    City  \
# 2067      2092    94560        CA    CA  Newark
#
#                               Metro      CountyName  2000-01-31  2000-02-29  \
# 2067  San Francisco-Oakland-Hayward  Alameda County    286072.0    287302.0
#
#       2000-03-31  ...  2021-10-31  2021-11-30  2021-12-31  2022-01-31  \
# 2067    289909.0  ...   1126337.0   1137833.0   1153492.0   1176325.0
#
#       2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31
# 2067   1202658.0   1237038.0   1267185.0   1285443.0   1282171.0   1268815.0
#
# [1 rows x 278 columns]

# %%
zip1_df = df[zipcode1_bool]
zip2_df = df[zipcode2_bool]

# %%
zip1_df.set_index('City')
zip2_df.set_index('City')
# Out:
#         SizeRank  Zipcode StateName State                          Metro  \
# City
# Newark      2092    94560        CA    CA  San Francisco-Oakland-Hayward
#
#             CountyName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  ...  \
# City                                                                    ...
# Newark  Alameda County    286072.0    287302.0    289909.0    299201.0  ...
#
#         2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# City
# Newark   1126337.0   1137833.0   1153492.0   1176325.0   1202658.0
#
#         2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31
# City
# Newark   1237038.0   1267185.0   1285443.0   1282171.0   1268815.0
#
# [1 rows x 277 columns]

# %%
new_df = pd.concat([zip1_df,zip2_df], axis=0)
print(new_df)
# Out:
#        SizeRank  Zipcode StateName State    City  \
# 12958     13213     2108        MA    MA  Boston
# 2067       2092    94560        CA    CA  Newark
#
#                                Metro      CountyName  2000-01-31  2000-02-29  \
# 12958        Boston-Cambridge-Newton  Suffolk County         NaN         NaN
# 2067   San Francisco-Oakland-Hayward  Alameda County    286072.0    287302.0
#
#        2000-03-31  ...  2021-10-31  2021-11-30  2021-12-31  2022-01-31  \
# 12958         NaN  ...   3456099.0   3459811.0   3494929.0   3511917.0
# 2067     289909.0  ...   1126337.0   1137833.0   1153492.0   1176325.0
#
#        2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31
# 12958   3533877.0   3539437.0   3570309.0   3585814.0   3604128.0   3604314.0
# 2067    1202658.0   1237038.0   1267185.0   1285443.0   1282171.0   1268815.0
#
# [2 rows x 278 columns]

# %%
new_df.head()
# Out:
#        SizeRank  Zipcode StateName State    City  \
# 12958     13213     2108        MA    MA  Boston
# 2067       2092    94560        CA    CA  Newark
#
#                                Metro      CountyName  2000-01-31  2000-02-29  \
# 12958        Boston-Cambridge-Newton  Suffolk County         NaN         NaN
# 2067   San Francisco-Oakland-Hayward  Alameda County    286072.0    287302.0
#
#        2000-03-31  ...  2021-10-31  2021-11-30  2021-12-31  2022-01-31  \
# 12958         NaN  ...   3456099.0   3459811.0   3494929.0   3511917.0
# 2067     289909.0  ...   1126337.0   1137833.0   1153492.0   1176325.0
#
#        2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31
# 12958   3533877.0   3539437.0   3570309.0   3585814.0   3604128.0   3604314.0
# 2067    1202658.0   1237038.0   1267185.0   1285443.0   1282171.0   1268815.0
#
# [2 rows x 278 columns]

# %%
new_df = new_df.set_index('City')

# %%
valuations = new_df.iloc[:, 7:]
valuations
# Out:
#         2000-02-29  2000-03-31  2000-04-30  2000-05-31  2000-06-30  \
# City
# Boston         NaN         NaN         NaN         NaN         NaN
# Newark    287302.0    289909.0    299201.0    311656.0    321025.0
#
#         2000-07-31  2000-08-31  2000-09-30  2000-10-31  2000-11-30  ...  \
# City                                                                ...
# Boston         NaN         NaN         NaN         NaN         NaN  ...
# Newark    328165.0    332606.0    340477.0    346807.0    353509.0  ...
#
#         2021-10-31  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# City
# Boston   3456099.0   3459811.0   3494929.0   3511917.0   3533877.0
# Newark   1126337.0   1137833.0   1153492.0   1176325.0   1202658.0
#
#         2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31
# City
# Boston   3539437.0   3570309.0   3585814.0   3604128.0   3604314.0
# Newark   1237038.0   1267185.0   1285443.0   1282171.0   1268815.0
#
# [2 rows x 270 columns]

# %%
valuations.T.plot()
plt.title('Valuation Comparison')
plt.xlabel('Years')
plt.ylabel('Avg Valuation in Millions')
plt.show()

# %% [markdown]
# Sources used:
# https://towardsdatascience.com/23-efficient-ways-of-subsetting-a-pandas-dataframe-6264b8000a77
#
# https://stackoverflow.com/questions/54315627/difference-between-and-and-in-pandas
#
# https://stackoverflow.com/questions/63667387/plotly-how-to-plot-a-line-chart-from-two-rows-of-data
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html#pandas.DataFrame.set_index
#
# https://stackoverflow.com/questions/41747039/how-to-plot-rows-in-dataframe
